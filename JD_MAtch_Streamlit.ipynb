# %%
import streamlit as st
import pandas as pd
import json
import os
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import Chroma
from langchain.chains import LLMChain
from langchain.prompts import PromptTemplate
from langchain.document_loaders import UnstructuredURLLoader
from azureai import AzureAI
from appconfig import AppConfig

class JobProfileMatcher:
    def __init__(self):
        # Initialize configuration and clients
        self.config = AppConfig()
        self.azure_ai = AzureAI(self.config)
        self.llm = self.azure_ai.get_client()
        self.embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
        self.chroma_db_name = "jd_chroma_db"
        self.chroma_persist_dir = "chroma_db"

        # Load or initialize Chroma DB
        if os.path.exists(self.chroma_persist_dir) and os.listdir(self.chroma_persist_dir):
            self.chroma_db = Chroma(
                collection_name=self.chroma_db_name,
                embedding_function=self.embeddings,
                persist_directory=self.chroma_persist_dir
            )
        else:
            self.chroma_db = Chroma(
                collection_name=self.chroma_db_name,
                embedding_function=self.embeddings,
                persist_directory=self.chroma_persist_dir
            )

    def preprocess_jd(self, row):
        combined_text = f"""
        Title: {row.get('Title', 'N/A')}
        Description: {row.get('Description', 'N/A')}
        Skills: {row.get('Skills', 'N/A')}
        Location: {row.get('Location', 'N/A')}
        Experience: {row.get('Experience', 'N/A')}
        Salary: {row.get('Salary', 'N/A')}
        """
        return combined_text.strip()

    def extract_profile_details(self, profile_text):
        # Define the LLM and prompt for profile extraction
        prompt = PromptTemplate(
            input_variables=["profile_text"],
            template="""
            The scraped text is from the career's page of a website.
            Your job is to extract the job postings and return them in JSON format containing the
            following keys:
            Title, Description, Skills, Location, Experience, Salary.
            Profile Text:
            {profile_text}
            """
        )

        chain = LLMChain(llm=self.llm, prompt=prompt)
        response = chain.run(profile_text)

        try:
            profile_details = json.loads(response)
            return profile_details
        except json.JSONDecodeError:
            st.error("Error: LLM response is not valid JSON. Please check the response format.")
            st.stop()

    def store_job_descriptions(self, jd_file):
        jd_df = pd.read_csv(jd_file)
        jd_df["Combined"] = jd_df.apply(self.preprocess_jd, axis=1)

        for _, row in jd_df.iterrows():
            jd_text = row["Combined"]
            self.chroma_db.add_texts([jd_text], metadatas={"Title": row["Title"]})

        self.chroma_db.persist()
        st.success("Job Descriptions stored in Chroma DB!")

    def process_profiles(self, profile_links):
        for link in profile_links:
            try:
                loader = UnstructuredURLLoader(urls=[link])
                documents = loader.load()
                profile_text = " ".join(doc.page_content for doc in documents)
                profile_details = self.extract_profile_details(profile_text)

                combined_profile_text = self.preprocess_jd(pd.Series(profile_details))
                self.chroma_db.add_texts([combined_profile_text], metadatas=profile_details)
            except Exception as e:
                st.error(f"Error processing URL {link}: {e}")
                st.stop()

        self.chroma_db.persist()
        st.success("Profiles stored in Chroma DB!")

    def match_profiles(self, jd_file):
        jd_df = pd.read_csv(jd_file)
        jd_df["Combined"] = jd_df.apply(self.preprocess_jd, axis=1)
        results = []

        for _, row in jd_df.iterrows():
            jd_text = row["Combined"]
            matches = self.chroma_db.similarity_search(jd_text, top_k=3)
            for match in matches:
                match_percent = match["score"] * 100
                results.append({
                    "JD": jd_text,
                    "Matched Profile Title": match["metadata"].get("Title", "Unknown"),
                    "Matching Percentage": f"{match_percent:.2f}%"
                })

        return results

# Streamlit App
st.title("Job Profile Matcher")
matcher = JobProfileMatcher()

# Step 1: Upload CSV File
st.header("Step 1: Upload Job Descriptions (CSV)")
jd_file = st.file_uploader("Upload JD CSV File", type="csv")
if jd_file and st.button("Store Job Descriptions"):
    matcher.store_job_descriptions(jd_file)

# Step 2: Enter Profile Links
st.header("Step 2: Provide Profile Links")
profile_links = st.text_area("Enter up to 4 profile links (one per line)").splitlines()
if profile_links and st.button("Process Profiles"):
    matcher.process_profiles(profile_links)

# Step 3: Match Profiles
st.header("Step 3: Match Profiles with JDs")
if jd_file and st.button("Match Profiles"):
    results = matcher.match_profiles(jd_file)
    for result in results:
        st.write(result)
# Out:
# 2024-12-19 17:38:22.956 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 17:38:22.956 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# KUBERNETES_SERVICE_PORT_HTTPS=
# NODE_MAX_SPACE_SIZE=4096
# KUBERNETES_SERVICE_PORT=
# no_proxy=localhost,127.0.0.1,github.com,.github.com,.npmjs.org,.yarnpkg.com,npm.sap.com,.maven.apache.org,.repo-cache.svc.cluster.local
# SAP_UI_BOOTSTRAP_URL=https://sapui5.hana.ondemand.com
# CF_API_ENDPOINT=https://api.cf.eu10.hana.ondemand.com
# HOSTNAME=workspaces-ws-c9pr6-deployment-7699d4cd86-vx9v5
# INTERNAL_LANDSCAPE=internalFalse
# SUBACCOUNT_ID=d79438d3-3873-4da0-9769-5ba543ad9894
# WING_EXT_INIT_PHASE_FIN_FILES=/extbin/simple-ext-installer.fin
# NODE_OPTIONS=--max-old-space-size=4096
# SIMPLE_EXTENSION_METADATA=...,...,...,...,...,...,...
# NODE_EXTRA_CA_CERTS=/etc/ssl/certs/ca-certificates.crt
# LANDSCAPE_NAME=eu10
# BAS_DEFAULT_NODEJS_VERSION=20.12.0
# externalEntrypoint=https://coe-asset-b9jxgzf0.eu10cf.applicationstudio.cloud.sap
# BAS_DEFAULT_JAVA_VERSION=sapmachine-21.0.2
# EDITOR=code
# PWD=/local/source/openvscode-server
# BUILD_CODE_PLAN=standard
# NO_UPDATE_NOTIFIER=true
# USER_NAME=srrs@deloitte.com
# HOME=/home/user
# KUBERNETES_PORT_443_TCP=
# TENANT_PLAN=standard-edition
# BAS_DEFAULT_PYTHON_VERSION=3.11.2
# DESTINATION_PROXY_URL=http://secure-outbound-connectivity.webide-system
# SWA_FIELD_MAPPING=
# ASDF_DATA_DIR=/home/user/.asdf-inst
# https_proxy=http://127.0.0.1:8887
# OUTPUT_CHANNEL_TRACE_LOCATION=/extbin/generators/simple-extension-yo-install-output.txt
# SWA_TARGET_SITE_URL=https://webanalytics2.cfapps.eu10.hana.ondemand.com/tracker/log
# TENANT_SUBDOMAIN=coe-asset-b9jxgzf0
# SWA_MINIMAL_ALLOWED_VERSION=1.2.11
# TENANT_NAME=coe-asset-b9jxgzf0
# LANDSCAPE_ENVIRONMENT=live
# CF_PLUGIN_HOME=/local/cfplugins
# WS_BASE_URL=https://workspaces-ws-c9pr6.eu10.applicationstudio.cloud.sap/
# _SHARED_ENV=BUILD_CODE_PLAN: standard
# CF_API_ENDPOINT: https://api.cf.eu10.hana.ondemand.com
# DESTINATION_PROXY_URL: http://secure-outbound-connectivity.webide-system
# EXT_DESTINATION_PROXY_URL_HOST: eu10.applicationstudio.cloud.sap
# H2O_URL: https://coe-asset-b9jxgzf0.eu10cf.applicationstudio.cloud.sap
# HTTP_PROXY: http://127.0.0.1:8887
# HTTPS_PROXY: http://127.0.0.1:8887
# INTERNAL_LANDSCAPE: internalFalse
# LANDSCAPE_ENVIRONMENT: live
# LANDSCAPE_INFRASTRUCTURE: aws
# LANDSCAPE_NAME: eu10
# NO_PROXY: localhost,127.0.0.1,github.com,.github.com,.npmjs.org,.yarnpkg.com,npm.sap.com,.maven.apache.org,.repo-cache.svc.cluster.local
# NODE_MAX_SPACE_SIZE: "4096"
# NPM_CFG_REGISTRY: https://registry.npmjs.org
# NPM_CFG_SAP_REGISTRY: https://npm.sap.com/
# NPM_CONFIG_USERCONFIG: /home/user/.npmrc
# SAP_UI_BOOTSTRAP_URL: https://sapui5.hana.ondemand.com
# SIMPLE_EXTENSION_METADATA: ...,...,...,...,...,...,...
# SUBACCOUNT_ID: d79438d3-3873-4da0-9769-5ba543ad9894
# SWA_EXCLUDED_ACCOUNTS: 
# SWA_FIELD_MAPPING: ""
# SWA_MINIMAL_ALLOWED_VERSION: 1.2.11
# SWA_TARGET_SITE_TOKEN: 95c7f8db-5d5a-43ba-8dfd-4b8e20486614
# SWA_TARGET_SITE_URL: https://webanalytics2.cfapps.eu10.hana.ondemand.com/tracker/log
# SWA_USER_ANON: literalTrue
# TENANT_PLAN: standard-edition
# TENANT_SUBDOMAIN: coe-asset-b9jxgzf0
# WING_EXT_INIT_PHASE_FIN_FILES: /extbin/simple-ext-installer.fin
# externalEntrypoint: https://coe-asset-b9jxgzf0.eu10cf.applicationstudio.cloud.sap
# http_proxy: http://127.0.0.1:8887
# https_proxy: http://127.0.0.1:8887
# no_proxy: localhost,127.0.0.1,github.com,.github.com,.npmjs.org,.yarnpkg.com,npm.sap.com,.maven.apache.org,.repo-cache.svc.cluster.local
# ownerFullName: Sreenivasan RS
# USER_NAME: "srrs@deloitte.com"
# WS_BASE_URL: https://workspaces-ws-c9pr6.eu10.applicationstudio.cloud.sap/
# WORKSPACE_ID: "workspaces-ws-c9pr6"
# TENANT_NAME: "coe-asset-b9jxgzf0"
# TENANT_ID: "d79438d3-3873-4da0-9769-5ba543ad9894"
# # Remove K8S env vars from shared env
# KUBERNETES_SERVICE_PORT_HTTPS:
# KUBERNETES_SERVICE_PORT:
# KUBERNETES_PORT_443_TCP:
# KUBERNETES_PORT_443_TCP_PROTO:
# KUBERNETES_PORT_443_TCP_ADDR:
# KUBERNETES_SERVICE_HOST:
# KUBERNETES_PORT:
# KUBERNETES_PORT_443_TCP_PORT:
# TENANT_LANDSCAPE_LABEL=n/a
# ASDF_DIR=/home/user/.asdf
# NO_PROXY=localhost,127.0.0.1,github.com,.github.com,.npmjs.org,.yarnpkg.com,npm.sap.com,.maven.apache.org,.repo-cache.svc.cluster.local
# NPM_CONFIG_USERCONFIG=/home/user/.npmrc
# VISUAL=code
# MBT_USE_DEFAULT="true"
# SHLVL=0
# LANDSCAPE_INFRASTRUCTURE=aws
# GIT_EDITOR=code --wait
# HTTPS_PROXY=http://127.0.0.1:8887
# SWA_USER_ANON=literalTrue
# KUBERNETES_PORT_443_TCP_PROTO=
# HTTP_PROXY=http://127.0.0.1:8887
# TENANT_ID=d79438d3-3873-4da0-9769-5ba543ad9894
# http_proxy=http://127.0.0.1:8887
# KUBERNETES_PORT_443_TCP_ADDR=
# NPM_CFG_REGISTRY=https://registry.npmjs.org
# H2O_URL=https://coe-asset-b9jxgzf0.eu10cf.applicationstudio.cloud.sap
# ownerFullName=Sreenivasan RS
# NODE_PATH=/extbin/npm/docker/lib/node_modules:/extbin/npm/globals/lib/node_modules:/managed-content/globals/pnpm/5/node_modules:/extbin/globals/pnpm/5/node_modules
# SWA_EXCLUDED_ACCOUNTS=
# KUBERNETES_SERVICE_HOST=api.eu10-prod.prod-aws.internal.live.k8s.ondemand.com
# KUBERNETES_PORT=
# KUBERNETES_PORT_443_TCP_PORT=
# BROWSER=open-browser
# PATH=/home/user/projects/JD/.venv/bin:/extbin/local/openvscode-server/bin/remote-cli:/home/user/.asdf-inst/shims:/home/user/.asdf/bin:/home/user/.node_modules_global/bin:/home/user/.local/bin:/extbin/bin:/extbin/npm/docker/bin:/extbin/npm/globals/bin:/managed-content/globals/pnpm/bin:/extbin/globals/pnpm/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin
# WORKSPACE_ID=workspaces-ws-c9pr6
# SWA_TARGET_SITE_TOKEN=95c7f8db-5d5a-43ba-8dfd-4b8e20486614
# NPM_CFG_SAP_REGISTRY=https://npm.sap.com/
# SIMPLE_EXT_NPMRC=/tmp/simple-ext/.npmrc
# EXT_DESTINATION_PROXY_URL_HOST=eu10.applicationstudio.cloud.sap
# OLDPWD=/home/user/.asdf
# LOG_CONFIG_PATH=/home/user/.webide/logs/sapTheiaExtLogConfig.yaml
# _=/home/user/projects/JD/.venv/bin/python
# VSCODE_CWD=/local/source/openvscode-server
# VSCODE_NLS_CONFIG={"userLocale":"en","osLocale":"en","resolvedLanguage":"en","defaultMessagesFile":"/extbin/local/openvscode-server/out/nls.messages.json","locale":"en","availableLanguages":{}}
# VSCODE_HANDLES_SIGPIPE=true
# LS_COLORS=
# VSCODE_AMD_ENTRYPOINT=vs/workbench/api/node/extensionHostProcess
# VSCODE_HANDLES_UNCAUGHT_ERRORS=true
# ELECTRON_RUN_AS_NODE=1
# VSCODE_IPC_HOOK_CLI=/tmp/vscode-ipc-45bd62d6-845d-4f8d-ad0c-ad136d82ddd7.sock
# PYTHONUNBUFFERED=1
# AZURE_DEPLOYMENT_ID_4O=dff8ea76f841688c
# SAP_ENDPOINT_URL_GPT4O=https://api.ai.prod.eu-central-1.aws.ml.hana.ondemand.com
# SERP_API_KEY=581a16b1da3d5cc007c68da74265770f169d232360e2ac2a0dfb78f99a54f3a0
# ENV=LOCAL
# TEMPERATURE=0.0
# TWITTER_ACCESS_TOKEN_SECRET=
# MODEL=gpt-4o
# VIRTUAL_ENV=/home/user/projects/JD/.venv
# TWITTER_CONSUMER_KEY=
# AICORE_RESOURCE_GROUP=default
# TWITTER_ACCESS_TOKEN=
# SAP_API_VERSION=2023-05-15
# SAP_CLIENT_SECRET=3a1271b2-eb3c-4d6b-84ed-362406d7721a$sBbx_NWiYqxMo_M1INbnTYULbelgp2uYk3kXNtgEKzY=
# PYTHONIOENCODING=utf-8
# VIRTUAL_ENV_PROMPT=(.venv)
# TWITTER_CONSUMER_SECRET=
# SAP_CLIENT_ID=sb-ba2bb4b5-c67c-4bff-ac21-96c32630e333!b501469|aicore!b540
# PS1=(.venv)
# MAX_TOKENS=256
# SAP_PROVIDER_URL=https://coe-asset-b9jxgzf0.authentication.eu10.hana.ondemand.com
# LC_CTYPE=C.UTF-8
# PYDEVD_IPYTHON_COMPATIBLE_DEBUGGING=1
# PYDEVD_USE_FRAME_EVAL=NO
# TERM=xterm-color
# CLICOLOR=1
# FORCE_COLOR=1
# CLICOLOR_FORCE=1
# PAGER=cat
# GIT_PAGER=cat
# MPLBACKEND=Agg
# KMP_DUPLICATE_LIB_OK=True
# KMP_INIT_AT_FORK=FALSE
# 2024-12-19 17:38:24.446 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 17:38:24.447 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 17:38:24.447 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 17:38:24.448 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 17:38:24.448 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 17:38:24.448 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 17:38:24.448 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 17:38:24.449 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 17:38:24.449 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 17:38:24.449 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 17:38:24.449 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 17:38:24.449 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 17:38:24.450 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 17:38:24.450 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 17:38:24.450 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 17:38:24.451 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 17:38:24.451 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
